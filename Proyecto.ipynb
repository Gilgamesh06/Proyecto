# %% [markdown]
# # Proyecto: `Clasificacion de cataratas en imagenes oculares.`
#
# <hr>
#
# * **Integrantes**
#     * Luigi Orlando Garcia Duarte
#     * Juan Jose Rincon
#     * Juan Pablo Arias
#
# * **Curso**
#     * Inteligencia Arificial II
#
# * **Grupo**
#     * F1
#
# * **Profesor**
#     * Willian romero

# %% [markdown]
# ## Introduccion
#
# 1. **Cataratas**
#
#     * Las Cataratas son una condicción ocular en la que el cristalino (La lente natural del ojo se vuelve opaco, lo que dificulta la visión). El cristalino normalmente se transparenta y permite que la luz pase a la retina, pero cuando se desarrolla catarata, la visión puede volverse borrosa o nublada.
#
# 2. **Causas**
#     * Las causas gerealmente se desarrollan como parte del proceso de envejecimiento natural, pero también puede aparecer debido a:
#         * **Envejecimiento**
#         * **Exposicion prolongada a la luz ultravioleta**
#         * **Uso prolongado de medicamenteos esteroides**
#         * **Lesion o traumatismos oculares**
#         * **Diabetes**
#         * **Tabaquismo**
#         * **Factores genéticos**
#
# 3. **Características**
#     * Los síntomas de las cataratas suele desarrollarse gradualmente, e incluyen:
#         * **Vision borrosa o nublada**
#         * **Colores desviados o amarillentos**
#         * **Dificultada para ver en la noche**
#         * **Sensibilidad a la luz**
#         * **Aparacíon de halos alrededor de las luces**
#         * **Visión doble en un ojo**
#
# 4. **Tratamientos**
#     * El unico tratamiento definitivo a las cataratas es la **cirugia**, ya que no hay medicamentos o gotas que pueden eliminar la opacidad del critalino.
#     * **Tipos de Cirugías:**
#
#         1. **Facoemulsificación**
#
#             * Funcionamiento:Se usa ultrasonido para romper la catarata, y los fragmentos se aspiran fuera del ojo. Después, se inserta una lente intraocular (LIO) en el lugar del cristalino dañado.
#             * Ideal para: pacientes con cataratas que no están muy avanzadas, cuando el cristalino aun no esta extremadamente endurecido.
#             * Requerimientos: La catarata debe ser lo suficiente blanda para que el ultrasonido pueda romperla sin complicaciones. Adecuado para pacientes con pupilas que pueden dilatarse bien durante cirugía.
#
#         2. **Extracción extracapsular**
#
#             * Funcionamiento: Cosiste en remover manualmente la parte opaca del cristalino. Requiere una incisión mas grande.
#             * Ideal para: Cataratas mas duras y avanzadas, cuando el cristalino se ha vuelto muy denso. Casos en los que la facoemulsificación no seria efectiva.
#             * Requerimientos: EL cristalino esta muy endurecido y no puede ser roto fácilmente por el ultrasonido.
#
#         3. **Cirugía láser de cataratas**
#
#             * Funcionamiento: Se utiliza un láser para hacer las incisiones en el ojo y fragmentar el cristalino antes de aspirarlo. A veces se considera una opción mas precisa y puede facilitar una recuperación mas rápida.
#             * Ideal para: Personas que prefieren un procedimiento mas preciso o aquellos que tiene alguna deformidad en el ojo que podría hacer mas complicada una cirugía manual.
#             * Requerimientos: Debe haber una evaluación completa para determinar si el paciente es candidato para la cirugía liases. ya que no todas los casos de cataratas se benefician del uso del láser.

# %% [markdown]
# ## Justificación
#
# * Como pudimos ver las cataratas son complejas y su única forma de tratamiento definitivo disponible es por medio de cirugía,existen varias de estas las cuales depende de requerimientos para poder realizarlas, Es decir no todas las cataratas se pueden tratar con el mismo método por lo cual requiere un análisis exhaustivo por el personal calificado para determinar si es necesario que el paciente se realiza una cirugía y que tipo de cirugía. Siendo esto un proceso largo el cual podría acortarse con el uso de la tecnología agilizando el proceso para el personal calificado donde ya tengan cierta parte del trabajo tedioso hecho y pueda concentrarse solo en la realización de diagnósticos en pacientes previamente clasificados.

# %% [markdown]
# ## Objetivos y Alcance
#
# 1. **Objetivos del proyecto:**
#
#     * Desarrollar un modelo de inteligencia artificial (IA): Crear un modelo de deep learning que, mediante imágenes oculares, sea capaz de identificar la presencia de cataratas
#     * Clasificación del Grado de cataratas: EL modelo debe poder clasificar las cataratas en diferentes grados (normal (sin parecencia de cataratas), iniciales , avanzadas)
#     * Comparación de modelo CNN Y DNN: Buscaremos comparar el desarrollo de los dos anteriores objetivos utilizando dos diferentes tipos de redes neuronales CNN y DNN y buscaremos determinar cual fue mas precisa , eficiente ventajas y desventajas de su uso para este caso.
#     * Recomendación de tipo de Cirugía: Con base en las predicción determinada por el modelo definiremos si el paciente debe o no tener cirugía y que tipo de cirugías podría ser aplicables.Alcances del proyecto:
#     * Reducir el tiempo de diagnostico: Automatizar el proceso de diagnostico mediante el uso de imágenes oculares para acelerar el tiempo de evaluación y determinación de la necesidad de cirugía.
#     * Accesibilidad de tratamiento: La automatización de diagnostico puede permitir la detección de esta afección en sonaos rurales donde es difícil encontrar especialistas.
#     * Mayor precisión en el diagnostico: Al automatizar ciertos aspectos del diagnostico permite al personal calificado tener mayor tiempo y claridad para la definición de un diagnostico final.
#     * Integración con sistemas de diagnóstico clínico: El modelo puede integrarse con plataformas hospitalarias o clínicas para facilitar la interpretación médica y la recomendación de tratamientos.

# %% [markdown]
# ## Dataset
#
# *  El dataset contiene imagenes oculares divididos en tres directorios en (`train`, `test` y `validacion`) las cuales contiene subdirectorios divididos en tres categorias:
#     * **Immature**
#     * **Mature**
#     * **Normal**

# %% [markdown]
# ## Librerias

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
from PIL import Image
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Funcion `load_data`
#
# * genera las etiquetas a partir de los nombres de la carpeta que contienen las imagenes

# %%
def load_data(data_dir):
    X = []
    y = []
    classes = os.listdir(data_dir)  # Obtener las clases (subdirectorios)

    for label in classes:
        class_dir = os.path.join(data_dir, label)
        if os.path.isdir(class_dir):
            for img_file in os.listdir(class_dir):
                img_path = os.path.join(class_dir, img_file)
                img = Image.open(img_path).resize((150, 150))  # Cambia el tamaño según tus necesidades
                X.append(np.array(img))
                y.append(label)

    return np.array(X), np.array(y)

# Cargar los datos
X_train, y_train = load_data('Dataset/train')
X_valid, y_valid = load_data('Dataset/valid')
X_test, y_test = load_data('Dataset/test')

# %% [markdown]
# ## Imagenes

# %%
plt.figure(figsize=(15,15))
plt.subplot(441), plt.imshow(X_train[2], cmap = 'gray'), plt.xticks([]), plt.yticks([]);
plt.subplot(442), plt.imshow(X_train[4], cmap = 'gray'), plt.xticks([]), plt.yticks([]);
plt.subplot(443), plt.imshow(X_train[8], cmap = 'gray'),plt.xticks([]), plt.yticks([]);
plt.subplot(444), plt.imshow(X_train[16], cmap = 'gray'),plt.xticks([]), plt.yticks([]);
plt.subplot(445), plt.imshow(X_train[32], cmap = 'gray'), plt.xticks([]), plt.yticks([]);
plt.subplot(446), plt.imshow(X_train[64], cmap = 'gray'), plt.xticks([]), plt.yticks([]);
plt.subplot(447), plt.imshow(X_train[128], cmap = 'gray'),plt.xticks([]), plt.yticks([]);
plt.subplot(448), plt.imshow(X_train[256], cmap = 'gray'),plt.xticks([]), plt.yticks([]);

# %% [markdown]
# ## Tamaño del Dataset
#
# * **train**
#     * Contiene 1753 imagenes con tamaño de 150px x 150px.
# * **valid**
#     * Contiene 760 imagenes con tamaño de 150px x 150px.
# * **test**
#     * Contiene 714 imagenes con tamaño de 150px x 150px.

# %%
print(f"Train: {X_train.shape}")
print(f"Valid: {X_valid.shape}")
print(f"Test: {X_test.shape}")
# Out:
# Train: (1753, 150, 150, 3)
# Valid: (760, 150, 150, 3)
# Test: (714, 150, 150, 3)

# %%
print(f"Labels train: {y_train}")
print(f"Labels valid: {y_train}")
print(f"Labels test: {y_test}")
# Out:
# Labels train: ['Immature' 'Immature' 'Immature' ... 'Normal' 'Normal' 'Normal']
# Labels valid: ['Immature' 'Immature' 'Immature' ... 'Normal' 'Normal' 'Normal']
# Labels test: ['Immature' 'Immature' 'Immature' 'Immature' 'Immature' 'Immature'
#  'Immature' 'Immature' 'Immature' 'Immature' 'Immature' 'Immature'
#  'Immature' 'Immature' 'Immature' 'Immature' 'Immature' 'Immature'
#  'Immature' 'Immature' 'Immature' 'Immature' 'Immature' 'Immature'
#  'Immature' 'Immature' 'Immature' 'Immature' 'Immature' 'Immature'
#  'Immature' 'Immature' 'Immature' 'Immature' 'Immature' 'Immature'
#  'Immature' 'Immature' 'Immature' 'Immature' 'Immature' 'Immature'
#  'Immature' 'Immature' 'Immature' 'Immature' 'Immature' 'Immature'
#  'Immature' 'Immature' 'Immature' 'Immature' 'Immature' 'Immature'
#  'Immature' 'Immature' 'Immature' 'Immature' 'Immature' 'Immature'
#  'Immature' 'Immature' 'Immature' 'Immature' 'Immature' 'Immature'
# ...

# %% [markdown]
# ## Funcion `Codificacion`
#
# * **Codifica en los siguientes valores**
#
#     * `Normal` = 0
#     * `Immature` = 1
#     * `Mature` = 2

# %%
def Codificacion(y):
    labels = ['Normal','Immature','Mature']
    for i in range(len(y)):
        if (y[i] == labels[0]):
                y[i] = 0
        elif(y[i] == labels[1]):
             y[i] = 1
        else:
             y[i] = 2
    return np.array(y).astype(int)

# %% [markdown]
# ## Funcion `Cantidad`
#
# * Genera la cantidad de cada tipo de Lables por
#     * train
#     * test
#     * valid

# %%
def Cantidad(x):
    normal = 0
    immature = 0
    mature = 0 
    for i in range(len(x)):
        if(x[i] == 0):
            normal +=1;
        elif(x[i] == 1):
            immature +=1
        else:
            mature +=1 
    print(f"Cantidad: {len(x)}")
    print(f"Normal: {normal} ---> {round(normal/len(x),3)} ")
    print(f"Immature: {immature} ---> {round(immature/len(x),3)} ")
    print(f"Mature: {mature} ---> {round(mature/len(x),3)}")

# %%
y_train = Codificacion(y_train)
Cantidad(y_train)
# Out:
# Cantidad: 1753
# Normal: 597 ---> 0.341
# Immature: 567 ---> 0.323
# Mature: 589 ---> 0.336

# %%
y_test = Codificacion(y_test)
Cantidad(y_test)
# Out:
# Cantidad: 714
# Normal: 259 ---> 0.363
# Immature: 198 ---> 0.277
# Mature: 257 ---> 0.36

# %%
y_valid = Codificacion(y_valid)
Cantidad(y_valid)
# Out:
# Cantidad: 760
# Normal: 247 ---> 0.325
# Immature: 221 ---> 0.291
# Mature: 292 ---> 0.384

# %% [markdown]
# ## Funcion `Metricas`
#
# * Retorna las metricas principales de los modelos diseñados

# %%
def Metricas(model,X_test,y_test):
    from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
    # Predicciones en los datos de prueba

    y_pred_proba = model.predict(X_test)  # Probabilidades
    y_pred = y_pred_proba.argmax(axis=1)  # Etiquetas predichas
    
    # Métricas
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')  # Weighted por clases desbalanceadas
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')  # AUC para clasificación multiclase

    # Imprimir las métricas
    print(f"Accuracy: {accuracy:.2f}")
    print(f"Precision: {precision:.2f}")
    print(f"Recall: {recall:.2f}")
    print(f"F1-Score: {f1:.2f}")
    print(f"AUC: {auc:.2f}")

    # Classification report
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, target_names=['Normal', 'Immature', 'Mature']))
    return accuracy,precision,recall,f1, auc

# %% [markdown]
# ## Funcion `Grafica`
#
# * Grafica la perdidad y el accuracy en las diferentes epochs

# %%
def Grafica(history):
    import matplotlib.pyplot as plt

    # Crear una figura con dos subgráficas
    fig, axs = plt.subplots(2, 1, figsize=(12, 12))  # 2 filas, 1 columna

    # Graficar la pérdida
    axs[0].plot(history.history['loss'], label='Pérdida de entrenamiento')
    axs[0].plot(history.history['val_loss'], label='Pérdida de validación')
    axs[0].set_title('Pérdida de entrenamiento y validación')
    axs[0].set_xlabel('Épocas')
    axs[0].set_ylabel('Pérdida')
    axs[0].legend()

    # Graficar la precisión
    axs[1].plot(history.history['accuracy'], label='Accuracy de entrenamiento')
    axs[1].plot(history.history['val_accuracy'], label='Accuracy de validación')
    axs[1].set_title('Accuracy de entrenamiento y validación')
    axs[1].set_xlabel('Épocas')
    axs[1].set_ylabel('Accuracy')
    axs[1].legend()

    # Ajustar el espacio entre las subgráficas
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Funcion `Lista`
#
# * Almacena las metricas de los diferentes modelos.

# %%
lista_accuracy = []
lista_precision = []
lista_recall = []
lista_f1 = []
lista_auc = []
lista_tipo = []
lista_version = []

def Listas(accuracy,precision,recall,f1, auc, modelo, version):
    lista_accuracy.append(accuracy)
    lista_precision.append(precision)
    lista_recall.append(recall)
    lista_f1.append(f1)
    lista_auc.append(auc)
    lista_tipo.append(modelo)
    lista_version.append(version)

# %% [markdown]
# ## Modelo `DNN 1`

# %% [markdown]
# * **Estructura**
#     * Capa de entrada **flatten** recibe imagenes de *(150px,150px ,3)* las aplana para el procesamiento de la `DNN`.
#     * Capa oculta **Dense** de 64 neuronas con activacion `relu`.
#     * Capa de salida **softmax** de tres neuronas (**Tres clases:** `Normal`,`Immature`.`Mature`).
#     * Optimizador **Adam** con un learning rate de 0.001.
#     * Funcion de perida `sparse_categorical_crossentropy`.
#     * Metricas usadas: `accuracy`,`precision`,`auc`.
#     * 10 `epochs`.
#     * Batch size **32**.

# %%
import tensorflow as tf
from tensorflow.keras import Sequential, optimizers
from tensorflow.keras.layers import Dense, Flatten

# Creacion del modelo Inicial
model_dnn1 = Sequential()
model_dnn1.add(Flatten(input_shape=X_train.shape[1:]))  # Aplanar las imagenes
model_dnn1.add(Dense(64, activation='relu'))
model_dnn1.add(Dense(3, activation='softmax'))

# Compilar el modelo

model_dnn1.compile(optimizer=optimizers.Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
# Out:
# /home/lain/Notebook/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history_model_dnn1 = model_dnn1.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.3802 - loss: 2968.4617 - val_accuracy: 0.3816 - val_loss: 821.9045
# Epoch 2/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.4856 - loss: 663.9245 - val_accuracy: 0.3303 - val_loss: 1359.8169
# Epoch 3/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.5281 - loss: 580.2953 - val_accuracy: 0.5724 - val_loss: 387.4496
# Epoch 4/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.6174 - loss: 258.3467 - val_accuracy: 0.5750 - val_loss: 285.9081
# Epoch 5/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.5512 - loss: 343.9648 - val_accuracy: 0.5289 - val_loss: 469.4500
# Epoch 6/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.6576 - loss: 258.0271 - val_accuracy: 0.4066 - val_loss: 671.5767
# Epoch 7/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.6383 - loss: 296.5623 - val_accuracy: 0.6013 - val_loss: 223.8964
# Epoch 8/10
# ...

# %% [markdown]
# ### Metricas

# %%
accuracy,precision,recall,f1, auc = Metricas(model_dnn1,X_test,y_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Accuracy: 0.52
# Precision: 0.54
# Recall: 0.52
# F1-Score: 0.47
# AUC: 0.63
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.50      0.95      0.65       259
#     Immature       0.51      0.17      0.26       198
#       Mature       0.61      0.36      0.45       257
#
#     accuracy                           0.52       714
#    macro avg       0.54      0.49      0.45       714
# weighted avg       0.54      0.52      0.47       714

# %% [markdown]
# #### Guarda metricas en listas

# %%
Listas(accuracy,precision,recall,f1, auc,"DNN", 1 )

# %% [markdown]
# ### Grafica

# %%
Grafica(history_model_dnn1)

# %% [markdown]
# ### Conclusiones

# %% [markdown]
# ## Modelo `CNN 1`

# %% [markdown]
# * **Estructura**
#     * Capa Convolucional de 64 filtros con kernel de 3x3 activacion `relu`.
#     * Capa de aplanamiento Flattend().
#     * Capa Dense de 64 neuronas con activacion `relu`.
#     * Capa de salida Dense de 3 neuronas  (**Tres clases:** `Normal`,`Immature`.`Mature`).
#     * Optimizador **Adam** con un learning rate de 0.001.
#     * Funcion de perida `sparse_categorical_crossentropy`.
#     * Metricas usadas: `accuracy`,`precision`,`auc`.
#     * 10 `epochs`.
#     * Batch size **32**.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense


model_cnn1 = Sequential()
model_cnn1.add(Conv2D(64, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model_cnn1.add(Flatten())
model_cnn1.add(Dense(64, activation='relu'))
model_cnn1.add(Dense(3, activation='softmax'))

model_cnn1.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history_model_cnn1 = model_cnn1.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 74s 1s/step - accuracy: 0.3699 - loss: 5022.4355 - val_accuracy: 0.6487 - val_loss: 17.9489
# Epoch 2/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 72s 1s/step - accuracy: 0.7730 - loss: 9.8336 - val_accuracy: 0.7842 - val_loss: 4.9737
# Epoch 3/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9308 - loss: 1.5863 - val_accuracy: 0.8316 - val_loss: 4.2334
# Epoch 4/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9882 - loss: 0.2058 - val_accuracy: 0.8526 - val_loss: 3.7530
# Epoch 5/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9993 - loss: 0.0029 - val_accuracy: 0.8421 - val_loss: 3.7939
# Epoch 6/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9950 - loss: 0.0307 - val_accuracy: 0.8355 - val_loss: 3.9197
# Epoch 7/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - accuracy: 0.9958 - loss: 0.0170 - val_accuracy: 0.8329 - val_loss: 4.0039
# Epoch 8/10
# ...

# %% [markdown]
# ### Metricas

# %%
accuracy,precision,recall,f1, auc = Metricas(model_cnn1,X_test,y_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step
# Accuracy: 0.85
# Precision: 0.85
# Recall: 0.85
# F1-Score: 0.85
# AUC: 0.94
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.91      0.87      0.89       259
#     Immature       0.79      0.82      0.80       198
#       Mature       0.83      0.85      0.84       257
#
#     accuracy                           0.85       714
#    macro avg       0.84      0.85      0.84       714
# weighted avg       0.85      0.85      0.85       714

# %% [markdown]
# #### Guarda metricas en listas

# %%
Listas(accuracy,precision,recall,f1, auc,"CNN",1)

# %% [markdown]
# ### Grafica

# %%
Grafica(history_model_cnn1)

# %% [markdown]
# ## Modelo `DNN 2`

# %% [markdown]
# * En este modelo se aunmento el numero de neuronas.
# * Capa Dense de 64 --> 128 neuronas

# %%
import tensorflow as tf
from tensorflow.keras import Sequential, optimizers
from tensorflow.keras.layers import Dense, Flatten

# Creacion del modelo 2
model_dnn2 = Sequential()
model_dnn2.add(Flatten(input_shape=X_train.shape[1:]))  # Aplanar las imagenes
model_dnn2.add(Dense(128, activation='relu'))
model_dnn2.add(Dense(3, activation='softmax'))

# Compilar el modelo

model_dnn2.compile(optimizer=optimizers.Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
# Out:
# /home/lain/Notebook/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history_model_dnn2 = model_dnn2.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.3513 - loss: 6916.2568 - val_accuracy: 0.5000 - val_loss: 805.4465
# Epoch 2/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.4833 - loss: 516.5163 - val_accuracy: 0.5303 - val_loss: 245.3394
# Epoch 3/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.5155 - loss: 290.9469 - val_accuracy: 0.5171 - val_loss: 291.8848
# Epoch 4/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.5594 - loss: 245.1575 - val_accuracy: 0.5237 - val_loss: 240.3583
# Epoch 5/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.5525 - loss: 320.1646 - val_accuracy: 0.4579 - val_loss: 444.4111
# Epoch 6/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.5905 - loss: 260.2214 - val_accuracy: 0.4539 - val_loss: 357.6849
# Epoch 7/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - accuracy: 0.6076 - loss: 247.2580 - val_accuracy: 0.4632 - val_loss: 480.3047
# Epoch 8/10
# ...

# %% [markdown]
# ### Metricas

# %%
accuracy,precision,recall,f1, auc = Metricas(model_dnn2,X_test,y_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Accuracy: 0.59
# Precision: 0.68
# Recall: 0.59
# F1-Score: 0.58
# AUC: 0.71
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.97      0.40      0.57       259
#     Immature       0.50      0.59      0.54       198
#       Mature       0.53      0.77      0.63       257
#
#     accuracy                           0.59       714
#    macro avg       0.67      0.59      0.58       714
# weighted avg       0.68      0.59      0.58       714

# %% [markdown]
# #### Guardar metricas en listas

# %%
Listas(accuracy,precision,recall,f1, auc,"DNN",2)

# %% [markdown]
# ### Grafica

# %%
Grafica(history_model_dnn2)

# %% [markdown]
# ## Modelo `CNN 2`

# %% [markdown]
# * Aumento de neuronas capa Dense oculta 64 --> 128

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense


model_cnn2 = Sequential()
model_cnn2.add(Conv2D(64, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model_cnn2.add(Flatten())
model_cnn2.add(Dense(128, activation='relu'))
model_cnn2.add(Dense(3, activation='softmax'))

model_cnn2.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# /home/lain/Notebook/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-11-16 16:51:04.644029: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 717750272 exceeds 10% of free system memory.
# 2024-11-16 16:51:05.034153: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 717750272 exceeds 10% of free system memory.
# 2024-11-16 16:51:05.640303: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 717750272 exceeds 10% of free system memory.

# %%
history_model_cnn2 = model_cnn2.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 2024-11-16 16:51:53.478533: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 717750272 exceeds 10% of free system memory.
# 2024-11-16 16:51:54.592288: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 717750272 exceeds 10% of free system memory.
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.3599 - loss: 13193.0020 - val_accuracy: 0.4776 - val_loss: 22.7926
# Epoch 2/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 129s 2s/step - accuracy: 0.6838 - loss: 9.7223 - val_accuracy: 0.7105 - val_loss: 5.2724
# Epoch 3/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 128s 2s/step - accuracy: 0.9384 - loss: 0.9139 - val_accuracy: 0.7342 - val_loss: 3.9200
# Epoch 4/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 135s 2s/step - accuracy: 0.9876 - loss: 0.0919 - val_accuracy: 0.7737 - val_loss: 3.5531
# Epoch 5/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - accuracy: 0.9948 - loss: 0.0319 - val_accuracy: 0.7618 - val_loss: 3.6253
# Epoch 6/10
# ...

# %% [markdown]
# ### Metricas

# %%
accuracy,precision,recall,f1, auc = Metricas(model_cnn2,X_test,y_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 243ms/step
# Accuracy: 0.81
# Precision: 0.81
# Recall: 0.81
# F1-Score: 0.81
# AUC: 0.93
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.83      0.87      0.85       259
#     Immature       0.79      0.78      0.79       198
#       Mature       0.80      0.77      0.79       257
#
#     accuracy                           0.81       714
#    macro avg       0.81      0.81      0.81       714
# weighted avg       0.81      0.81      0.81       714

# %% [markdown]
# #### Guardar metricas en listas

# %%
Listas(accuracy,precision,recall,f1, auc,"CNN",2)

# %% [markdown]
# ### Grafica

# %%
Grafica(history_model_cnn2)

# %% [markdown]
# ## Modelo `DNN 3`

# %% [markdown]
# * En este modelo se decidio aumentar el numero de capas
#     * Se agrego una capa mas de 64 neuronas con activacion `relu`

# %%
import tensorflow as tf
from tensorflow.keras import Sequential, optimizers
from tensorflow.keras.layers import Dense, Flatten

# Creacion del modelo 3
model_dnn3 = Sequential()
model_dnn3.add(Flatten(input_shape=X_train.shape[1:]))  # Aplanar las imagenes
model_dnn3.add(Dense(128, activation='relu'))
model_dnn3.add(Dense(64, activation='relu'))
model_dnn3.add(Dense(3, activation='softmax'))

# Compilar el modelo

model_dnn3.compile(optimizer=optimizers.Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
# Out:
# /home/lain/Notebook/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history_model_dnn3 = model_dnn3.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 101ms/step - accuracy: 0.3514 - loss: 3169.8748 - val_accuracy: 0.3921 - val_loss: 473.7987
# Epoch 2/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.4854 - loss: 354.8373 - val_accuracy: 0.4421 - val_loss: 506.0970
# Epoch 3/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.5097 - loss: 343.8321 - val_accuracy: 0.4408 - val_loss: 297.6497
# Epoch 4/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.5482 - loss: 253.7772 - val_accuracy: 0.5395 - val_loss: 307.5235
# Epoch 5/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 11s 118ms/step - accuracy: 0.5179 - loss: 401.7556 - val_accuracy: 0.4763 - val_loss: 251.6373
# Epoch 6/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 115ms/step - accuracy: 0.6123 - loss: 146.7878 - val_accuracy: 0.4579 - val_loss: 382.5746
# Epoch 7/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.5801 - loss: 178.2263 - val_accuracy: 0.4434 - val_loss: 194.7006
# Epoch 8/10
# ...

# %% [markdown]
# ### Metricas

# %%
accuracy,precision,recall,f1, auc = Metricas(model_dnn3,X_test,y_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Accuracy: 0.47
# Precision: 0.65
# Recall: 0.47
# F1-Score: 0.39
# AUC: 0.60
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.98      0.24      0.39       259
#     Immature       0.51      0.09      0.15       198
#       Mature       0.41      0.99      0.58       257
#
#     accuracy                           0.47       714
#    macro avg       0.64      0.44      0.38       714
# weighted avg       0.65      0.47      0.39       714

# %% [markdown]
# #### Guardar metricas en listas

# %%
Listas(accuracy,precision,recall,f1, auc,"DNN",3)

# %% [markdown]
# ### Grafica

# %%
Grafica(history_model_dnn3)

# %% [markdown]
# ## Modelo `CNN 3`

# %% [markdown]
# * En este modelo se aumento el numero de capaz convolucionales
#     * Se agrega una nueva capa convolucional de 32 filtros con kernel de 3x3 y funcion de activacion relu

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense


model_cnn3 = Sequential()
model_cnn3.add(Conv2D(64, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model_cnn3.add(Conv2D(32, (3, 3), activation='relu'))
model_cnn3.add(Flatten())
model_cnn3.add(Dense(128, activation='relu'))
model_cnn3.add(Dense(3, activation='softmax'))

model_cnn3.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# /home/lain/Notebook/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history_model_cnn3 = model_cnn3.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - accuracy: 0.4309 - loss: 2848.2766 - val_accuracy: 0.5750 - val_loss: 1.0718
# Epoch 2/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 190s 3s/step - accuracy: 0.7635 - loss: 0.6779 - val_accuracy: 0.6671 - val_loss: 0.8301
# Epoch 3/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 161s 3s/step - accuracy: 0.8927 - loss: 0.3220 - val_accuracy: 0.7250 - val_loss: 0.8626
# Epoch 4/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 151s 3s/step - accuracy: 0.9781 - loss: 0.0676 - val_accuracy: 0.7434 - val_loss: 1.1551
# Epoch 5/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 153s 3s/step - accuracy: 0.9948 - loss: 0.0237 - val_accuracy: 0.6618 - val_loss: 1.6486
# Epoch 6/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 210s 3s/step - accuracy: 0.9635 - loss: 0.1395 - val_accuracy: 0.6632 - val_loss: 1.7084
# Epoch 7/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 161s 3s/step - accuracy: 0.9974 - loss: 0.0147 - val_accuracy: 0.7132 - val_loss: 1.5692
# Epoch 8/10
# ...

# %% [markdown]
# ### Metricas

# %%
accuracy,precision,recall,f1, auc = Metricas(model_cnn3,X_test,y_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 439ms/step
# Accuracy: 0.71
# Precision: 0.71
# Recall: 0.71
# F1-Score: 0.70
# AUC: 0.89
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.75      0.85      0.80       259
#     Immature       0.60      0.64      0.62       198
#       Mature       0.76      0.61      0.68       257
#
#     accuracy                           0.71       714
#    macro avg       0.70      0.70      0.70       714
# weighted avg       0.71      0.71      0.70       714

# %% [markdown]
# #### Guardar metricas en listas

# %%
Listas(accuracy,precision,recall,f1, auc,"CNN",3)

# %% [markdown]
# ### Grafica

# %%
Grafica(history_model_cnn3)

# %% [markdown]
# ## Modelo `DNN 4`

# %% [markdown]
# * En este modelo se agregara una capa con dropout

# %%
import tensorflow as tf
from tensorflow.keras import Sequential, optimizers
from tensorflow.keras.layers import Dense, Flatten, Dropout

# Creacion del modelo 4
model_dnn4 = Sequential()
model_dnn4.add(Flatten(input_shape=X_train.shape[1:]))  # Aplanar las imagenes
model_dnn4.add(Dense(128, activation='relu'))
model_dnn4.add(Dropout(0.5))  # Agregar Dropout con una tasa del 50%
model_dnn4.add(Dense(64, activation='relu'))
model_dnn4.add(Dense(3, activation='softmax'))

# Compilar el modelo

model_dnn4.compile(optimizer=optimizers.Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
# Out:
# /home/lain/Notebook/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history_model_dnn4 = model_dnn4.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 117ms/step - accuracy: 0.3604 - loss: 2966.4460 - val_accuracy: 0.3829 - val_loss: 1.1025
# Epoch 2/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 108ms/step - accuracy: 0.3269 - loss: 1.1116 - val_accuracy: 0.3855 - val_loss: 1.0946
# Epoch 3/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 106ms/step - accuracy: 0.3356 - loss: 1.0983 - val_accuracy: 0.3855 - val_loss: 1.0948
# Epoch 4/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.3252 - loss: 1.0987 - val_accuracy: 0.3855 - val_loss: 1.0953
# Epoch 5/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.3373 - loss: 1.0990 - val_accuracy: 0.3855 - val_loss: 1.0952
# Epoch 6/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.3387 - loss: 1.0981 - val_accuracy: 0.3250 - val_loss: 1.0957
# Epoch 7/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - accuracy: 0.3529 - loss: 1.0986 - val_accuracy: 0.3250 - val_loss: 1.0958
# Epoch 8/10
# ...

# %% [markdown]
# ### Metricas

# %%
accuracy,precision,recall,f1, auc = Metricas(model_dnn4,X_test,y_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Accuracy: 0.36
# Precision: 0.13
# Recall: 0.36
# F1-Score: 0.19
# AUC: 0.50
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.36      1.00      0.53       259
#     Immature       0.00      0.00      0.00       198
#       Mature       0.00      0.00      0.00       257
#
#     accuracy                           0.36       714
#    macro avg       0.12      0.33      0.18       714
# weighted avg       0.13      0.36      0.19       714
# /home/lain/Notebook/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# #### Guardar metricas en listas

# %%
Listas(accuracy,precision,recall,f1, auc,"DNN",4)

# %% [markdown]
# ### Grafica

# %%
Grafica(history_model_dnn4)

# %% [markdown]
# ## Modelo `CNN 4`

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, Dropout


model_cnn4 = Sequential()
model_cnn4.add(Conv2D(64, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model_cnn4.add(Dropout(0.5))
model_cnn4.add(Conv2D(32, (3, 3), activation='relu'))
model_cnn4.add(Flatten())
model_cnn4.add(Dense(128, activation='relu'))
model_cnn4.add(Dense(3, activation='softmax'))

model_cnn4.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# /home/lain/Notebook/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history_model_cnn4 = model_cnn4.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 173s 3s/step - accuracy: 0.3216 - loss: 3088.0117 - val_accuracy: 0.3250 - val_loss: 1.0984
# Epoch 2/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 171s 3s/step - accuracy: 0.3518 - loss: 1.0981 - val_accuracy: 0.3250 - val_loss: 1.0983
# Epoch 3/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 191s 3s/step - accuracy: 0.3524 - loss: 1.0976 - val_accuracy: 0.3250 - val_loss: 1.0984
# Epoch 4/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 161s 3s/step - accuracy: 0.3630 - loss: 1.0969 - val_accuracy: 0.3250 - val_loss: 1.0981
# Epoch 5/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 201s 3s/step - accuracy: 0.3755 - loss: 1.0948 - val_accuracy: 0.3250 - val_loss: 1.0984
# Epoch 6/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 202s 3s/step - accuracy: 0.3772 - loss: 1.0908 - val_accuracy: 0.3421 - val_loss: 1.0960
# Epoch 7/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 201s 3s/step - accuracy: 0.4473 - loss: 1.0409 - val_accuracy: 0.3632 - val_loss: 1.0842
# Epoch 8/10
# ...

# %% [markdown]
# ### Metricas

# %%
accuracy,precision,recall,f1, auc = Metricas(model_cnn4,X_test,y_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 442ms/step
# Accuracy: 0.45
# Precision: 0.50
# Recall: 0.45
# F1-Score: 0.40
# AUC: 0.61
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.42      0.86      0.56       259
#     Immature       0.39      0.13      0.19       198
#       Mature       0.66      0.29      0.40       257
#
#     accuracy                           0.45       714
#    macro avg       0.49      0.43      0.39       714
# weighted avg       0.50      0.45      0.40       714

# %% [markdown]
# #### Guardar metricas en listas

# %%
Listas(accuracy,precision,recall,f1, auc,"CNN",4)

# %% [markdown]
# ### Grafica

# %%
Grafica(history_model_cnn4)

# %% [markdown]
# ## Modelo `DNN 5`

# %% [markdown]
# * Disminucion del dropout a 0.2

# %%
import tensorflow as tf
from tensorflow.keras import Sequential, optimizers
from tensorflow.keras.layers import Dense, Flatten, Dropout

# Creacion del modelo 5
model_dnn5 = Sequential()
model_dnn5.add(Flatten(input_shape=X_train.shape[1:]))  # Aplanar las imagenes
model_dnn5.add(Dense(128, activation='relu'))
model_dnn5.add(Dropout(0.2))  # Agregar Dropout con una tasa del 20%
model_dnn5.add(Dense(64, activation='relu'))
model_dnn5.add(Dense(3, activation='softmax'))

# Compilar el modelo

model_dnn5.compile(optimizer=optimizers.Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
# Out:
# /home/lain/Notebook/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history_model_dnn5 = model_dnn5.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 118ms/step - accuracy: 0.3726 - loss: 2114.5149 - val_accuracy: 0.4118 - val_loss: 78.3364
# Epoch 2/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 116ms/step - accuracy: 0.3326 - loss: 157.9276 - val_accuracy: 0.3250 - val_loss: 1.0968
# Epoch 3/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 108ms/step - accuracy: 0.3457 - loss: 1.0945 - val_accuracy: 0.3250 - val_loss: 1.0970
# Epoch 4/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 111ms/step - accuracy: 0.3339 - loss: 1.0959 - val_accuracy: 0.3250 - val_loss: 1.0965
# Epoch 5/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 110ms/step - accuracy: 0.3381 - loss: 1.0941 - val_accuracy: 0.3250 - val_loss: 1.0965
# Epoch 6/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.3427 - loss: 1.0932 - val_accuracy: 0.3250 - val_loss: 1.0964
# Epoch 7/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 112ms/step - accuracy: 0.3241 - loss: 1.0950 - val_accuracy: 0.3250 - val_loss: 1.0964
# Epoch 8/10
# ...

# %% [markdown]
# ### Metricas

# %%
accuracy,precision,recall,f1, auc = Metricas(model_dnn5,X_test,y_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Accuracy: 0.36
# Precision: 0.13
# Recall: 0.36
# F1-Score: 0.19
# AUC: 0.50
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.36      1.00      0.53       259
#     Immature       0.00      0.00      0.00       198
#       Mature       0.00      0.00      0.00       257
#
#     accuracy                           0.36       714
#    macro avg       0.12      0.33      0.18       714
# weighted avg       0.13      0.36      0.19       714
# /home/lain/Notebook/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# #### Guardar metricas en listas

# %%
Listas(accuracy,precision,recall,f1, auc,"DNN",5)

# %% [markdown]
# ### Grafica

# %%
Grafica(history_model_dnn5)

# %% [markdown]
# ## Modelo `CNN 5`

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, Dropout


model_cnn5 = Sequential()
model_cnn5.add(Conv2D(64, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model_cnn5.add(Dropout(0.2))
model_cnn5.add(Conv2D(32, (3, 3), activation='relu'))
model_cnn5.add(Flatten())
model_cnn5.add(Dense(128, activation='relu'))
model_cnn5.add(Dense(3, activation='softmax'))

model_cnn5.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# /home/lain/Notebook/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history_model_cnn5 = model_cnn5.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 177s 3s/step - accuracy: 0.4293 - loss: 2838.3259 - val_accuracy: 0.5671 - val_loss: 0.9760
# Epoch 2/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 160s 3s/step - accuracy: 0.6754 - loss: 0.7748 - val_accuracy: 0.6461 - val_loss: 0.8736
# Epoch 3/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 170s 3s/step - accuracy: 0.7415 - loss: 0.6516 - val_accuracy: 0.6105 - val_loss: 0.9307
# Epoch 4/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 160s 3s/step - accuracy: 0.7642 - loss: 0.5841 - val_accuracy: 0.6684 - val_loss: 1.0301
# Epoch 5/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 202s 3s/step - accuracy: 0.7806 - loss: 0.5054 - val_accuracy: 0.6750 - val_loss: 1.1355
# Epoch 6/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 171s 3s/step - accuracy: 0.8151 - loss: 0.3991 - val_accuracy: 0.7053 - val_loss: 1.4305
# Epoch 7/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 161s 3s/step - accuracy: 0.8956 - loss: 0.2524 - val_accuracy: 0.6842 - val_loss: 1.7894
# Epoch 8/10
# ...

# %% [markdown]
# ### Metricas

# %%
accuracy,precision,recall,f1, auc = Metricas(model_cnn5,X_test,y_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 11s 450ms/step
# Accuracy: 0.73
# Precision: 0.73
# Recall: 0.73
# F1-Score: 0.73
# AUC: 0.87
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.82      0.84      0.83       259
#     Immature       0.59      0.63      0.61       198
#       Mature       0.74      0.68      0.71       257
#
#     accuracy                           0.73       714
#    macro avg       0.72      0.72      0.72       714
# weighted avg       0.73      0.73      0.73       714

# %% [markdown]
# #### Guardar metricas en listas

# %%
Listas(accuracy,precision,recall,f1, auc,"CNN",5)

# %% [markdown]
# ### Grafica

# %%
Grafica(history_model_cnn5)

# %% [markdown]
# ## Guardar Metricas

# %%
dic = {
    "accuracy":lista_accuracy,
    "precision":lista_precision,
    "Recall":lista_recall,
    "F1 Score":lista_f1,
    "Auc":lista_auc,
    "Tipo modelo":lista_tipo,
    "Version":lista_version
}

# %%
data = pd.DataFrame(dic)
data
# Out:
#    accuracy  precision    Recall  F1 Score       Auc Tipo modelo  Version
# 0  0.460784   0.602613  0.460784  0.390888  0.801792         DNN        6
# 1  0.707283   0.712983  0.707283  0.706926  0.872555         CNN        6
# 2  0.855742   0.872676  0.855742  0.856409  0.964927         DNN        7
# 3  0.658263   0.676740  0.658263  0.656653  0.841584         CNN        7
# 4  0.831933   0.859846  0.831933  0.834178  0.948271         CNN        8

# %%
# Guardar el DataFrame en un archivo CSV

data.to_csv('data.csv', index=False)  # index=False para no guardar el índice

# %% [markdown]
# ## Modelo `DNN 6`

# %%
import tensorflow as tf
from tensorflow.keras import Sequential, optimizers
from tensorflow.keras.layers import Dense, Flatten ,BatchNormalization

# Creacion del modelo 5
model_dnn6 = Sequential()
model_dnn6.add(Flatten(input_shape=X_train.shape[1:]))  # Aplanar las imagenes
model_dnn6.add(Dense(128, activation='relu'))
model_dnn6.add(BatchNormalization())  # Normalización por lotes
model_dnn6.add(Dense(64, activation='relu'))
model_dnn6.add(Dense(3, activation='softmax'))

# Compilar el modelo

model_dnn6.compile(optimizer=optimizers.Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
# Out:
# 2024-11-18 18:24:33.870940: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-18 18:24:34.051892: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-18 18:24:34.208391: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1731972274.357078    5208 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1731972274.395892    5208 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
history_model_dnn6 = model_dnn6.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 107ms/step - accuracy: 0.5093 - loss: 1.0177 - val_accuracy: 0.4632 - val_loss: 1.9538
# Epoch 2/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - accuracy: 0.7149 - loss: 0.6998 - val_accuracy: 0.4789 - val_loss: 1.2427
# Epoch 3/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.7846 - loss: 0.5586 - val_accuracy: 0.5250 - val_loss: 1.1109
# Epoch 4/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - accuracy: 0.8625 - loss: 0.4314 - val_accuracy: 0.5395 - val_loss: 1.3315
# Epoch 5/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.8911 - loss: 0.3499 - val_accuracy: 0.5579 - val_loss: 1.5822
# Epoch 6/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - accuracy: 0.9224 - loss: 0.2654 - val_accuracy: 0.5763 - val_loss: 0.9794
# Epoch 7/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9540 - loss: 0.2066 - val_accuracy: 0.4776 - val_loss: 1.5378
# Epoch 8/10
# ...

# %% [markdown]
# ### Metricas

# %%
accuracy,precision,recall,f1, auc = Metricas(model_dnn6,X_test,y_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Accuracy: 0.46
# Precision: 0.60
# Recall: 0.46
# F1-Score: 0.39
# AUC: 0.80
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.41      0.96      0.58       259
#     Immature       0.64      0.18      0.28       198
#       Mature       0.77      0.18      0.29       257
#
#     accuracy                           0.46       714
#    macro avg       0.61      0.44      0.38       714
# weighted avg       0.60      0.46      0.39       714

# %% [markdown]
# #### Guardar metricas

# %%
Listas(accuracy,precision,recall,f1, auc,"DNN",6)

# %% [markdown]
# ### Grafica

# %%
Grafica(history_model_dnn6)

# %% [markdown]
# ## Modelo `CNN 6`

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, BatchNormalization


model_cnn6 = Sequential()
model_cnn6.add(Conv2D(64, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model_dnn6.add(BatchNormalization())  # Normalización por lotes
model_cnn6.add(Conv2D(32, (3, 3), activation='relu'))
model_cnn6.add(Flatten())
model_cnn6.add(Dense(128, activation='relu'))
model_cnn6.add(Dense(3, activation='softmax'))

model_cnn6.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# /home/lain/Notebook/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history_model_cnn6 = model_cnn6.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 142s 3s/step - accuracy: 0.4048 - loss: 1912.4541 - val_accuracy: 0.5671 - val_loss: 0.9711
# Epoch 2/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 140s 3s/step - accuracy: 0.7922 - loss: 0.6058 - val_accuracy: 0.7066 - val_loss: 0.6496
# Epoch 3/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 142s 3s/step - accuracy: 0.9572 - loss: 0.1335 - val_accuracy: 0.7566 - val_loss: 0.6905
# Epoch 4/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 140s 3s/step - accuracy: 0.9921 - loss: 0.0603 - val_accuracy: 0.7145 - val_loss: 1.9617
# Epoch 5/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 141s 3s/step - accuracy: 0.9979 - loss: 0.0085 - val_accuracy: 0.7211 - val_loss: 1.3297
# Epoch 6/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 140s 3s/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.7250 - val_loss: 1.5097
# Epoch 7/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 141s 3s/step - accuracy: 1.0000 - loss: 5.0379e-04 - val_accuracy: 0.6987 - val_loss: 2.1020
# Epoch 8/10
# ...

# %% [markdown]
# ### Metricas

# %%
accuracy,precision,recall,f1, auc = Metricas(model_cnn6,X_test,y_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 423ms/step
# Accuracy: 0.71
# Precision: 0.71
# Recall: 0.71
# F1-Score: 0.71
# AUC: 0.87
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.75      0.82      0.78       259
#     Immature       0.59      0.64      0.61       198
#       Mature       0.77      0.64      0.70       257
#
#     accuracy                           0.71       714
#    macro avg       0.70      0.70      0.70       714
# weighted avg       0.71      0.71      0.71       714

# %% [markdown]
# #### Guardar metricas

# %%
Listas(accuracy,precision,recall,f1, auc,"CNN",6)

# %% [markdown]
# ### Grafica

# %%
Grafica(history_model_cnn6)

# %% [markdown]
# ## Modelo `DNN 7`

# %%
import tensorflow as tf
from tensorflow.keras import Sequential, optimizers
from tensorflow.keras.layers import Dense, Flatten ,BatchNormalization

# Creacion del modelo 5
model_dnn7 = Sequential()
model_dnn7.add(Flatten(input_shape=X_train.shape[1:]))  # Aplanar las imagenes
model_dnn7.add(Dense(256, activation='relu'))
model_dnn7.add(BatchNormalization())  # Normalización por lotes
model_dnn7.add(Dense(128, activation='relu'))
model_dnn7.add(BatchNormalization())  # Normalización por lotes
model_dnn7.add(Dense(64, activation='relu'))
model_dnn7.add(Dense(3, activation='softmax'))

# Compilar el modelo

model_dnn7.compile(optimizer=optimizers.Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
# Out:
# /home/lain/Notebook/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history_model_dnn7 = model_dnn7.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 13s 201ms/step - accuracy: 0.5172 - loss: 1.0512 - val_accuracy: 0.3316 - val_loss: 3.0434
# Epoch 2/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.7931 - loss: 0.5648 - val_accuracy: 0.3684 - val_loss: 2.2855
# Epoch 3/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.8972 - loss: 0.3537 - val_accuracy: 0.5632 - val_loss: 1.0085
# Epoch 4/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - accuracy: 0.9053 - loss: 0.2818 - val_accuracy: 0.4605 - val_loss: 1.7076
# Epoch 5/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - accuracy: 0.9522 - loss: 0.1796 - val_accuracy: 0.7474 - val_loss: 0.6804
# Epoch 6/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 21s 202ms/step - accuracy: 0.9529 - loss: 0.1533 - val_accuracy: 0.6579 - val_loss: 0.9689
# Epoch 7/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - accuracy: 0.9721 - loss: 0.1104 - val_accuracy: 0.7184 - val_loss: 0.7272
# Epoch 8/10
# ...

# %% [markdown]
# ### Metricas

# %%
accuracy,precision,recall,f1, auc = Metricas(model_dnn7,X_test,y_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# Accuracy: 0.86
# Precision: 0.87
# Recall: 0.86
# F1-Score: 0.86
# AUC: 0.96
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.97      0.84      0.90       259
#     Immature       0.89      0.75      0.81       198
#       Mature       0.76      0.96      0.85       257
#
#     accuracy                           0.86       714
#    macro avg       0.87      0.85      0.85       714
# weighted avg       0.87      0.86      0.86       714

# %% [markdown]
# #### Guardar Metricas

# %%
Listas(accuracy,precision,recall,f1, auc,"DNN",7)

# %% [markdown]
# ### Grafica

# %%
Grafica(history_model_dnn7)

# %% [markdown]
# ## Modelo `CNN 7`

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, BatchNormalization


model_cnn7 = Sequential()
model_cnn7.add(Conv2D(128, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model_dnn7.add(BatchNormalization())  # Normalización por lotes
model_cnn7.add(Conv2D(64, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model_dnn7.add(BatchNormalization())  # Normalización por lotes
model_cnn7.add(Conv2D(32, (3, 3), activation='relu'))
model_cnn7.add(Flatten())
model_cnn7.add(Dense(128, activation='relu'))
model_cnn7.add(Dense(3, activation='softmax'))

model_cnn7.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# /home/lain/Notebook/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history_model_cnn7 = model_cnn7.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 387s 7s/step - accuracy: 0.3475 - loss: 943.4316 - val_accuracy: 0.4289 - val_loss: 1.0432
# Epoch 2/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 449s 7s/step - accuracy: 0.6012 - loss: 0.8519 - val_accuracy: 0.5632 - val_loss: 0.9037
# Epoch 3/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 437s 7s/step - accuracy: 0.8623 - loss: 0.5235 - val_accuracy: 0.6053 - val_loss: 1.0974
# Epoch 4/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 450s 7s/step - accuracy: 0.9265 - loss: 0.2368 - val_accuracy: 0.6368 - val_loss: 1.4369
# Epoch 5/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 393s 7s/step - accuracy: 0.9815 - loss: 0.0516 - val_accuracy: 0.6579 - val_loss: 1.6174
# Epoch 6/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 387s 7s/step - accuracy: 0.9996 - loss: 0.0147 - val_accuracy: 0.6566 - val_loss: 2.0334
# Epoch 7/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 449s 7s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6526 - val_loss: 2.1853
# Epoch 8/10
# ...

# %% [markdown]
# ### Metricas

# %%
accuracy,precision,recall,f1, auc = Metricas(model_cnn7,X_test,y_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step
# Accuracy: 0.66
# Precision: 0.68
# Recall: 0.66
# F1-Score: 0.66
# AUC: 0.84
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.65      0.75      0.69       259
#     Immature       0.58      0.70      0.64       198
#       Mature       0.78      0.54      0.64       257
#
#     accuracy                           0.66       714
#    macro avg       0.67      0.66      0.66       714
# weighted avg       0.68      0.66      0.66       714

# %% [markdown]
# #### Guardar Metricas

# %%
Listas(accuracy,precision,recall,f1, auc,"CNN",7)

# %% [markdown]
# ### Grafica

# %%
Grafica(history_model_cnn7)

# %% [markdown]
# ## Modelo `CNN 8`

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, BatchNormalization, Dropout

model_cnn8 = Sequential()

# Primera capa convolucional
model_cnn8.add(Conv2D(128, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model_cnn8.add(BatchNormalization())

# Segunda capa convolucional
model_cnn8.add(Conv2D(64, (3, 3), activation='relu'))

# Tercera capa convolucional
model_cnn8.add(Conv2D(32, (3, 3), activation='relu'))
model_cnn8.add(BatchNormalization())

# Aplanar la salida
model_cnn8.add(Flatten())

# Capa densa con Dropout
model_cnn8.add(Dense(128, activation='relu'))
model_cnn8.add(Dropout(0.2))  # Dropout con una tasa del 20%

# Capa de salida
model_cnn8.add(Dense(3, activation='softmax'))

# Compilación del modelo
model_cnn8.compile(optimizer='adam',
                   loss='sparse_categorical_crossentropy',
                   metrics=['accuracy'])
# Out:
# /home/lain/Notebook/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history_model_cnn8 = model_cnn8.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 453s 8s/step - accuracy: 0.4991 - loss: 29.9199 - val_accuracy: 0.3250 - val_loss: 763.9855
# Epoch 2/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 453s 8s/step - accuracy: 0.6781 - loss: 2.2376 - val_accuracy: 0.3513 - val_loss: 359.4247
# Epoch 3/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 458s 8s/step - accuracy: 0.6964 - loss: 0.8261 - val_accuracy: 0.3592 - val_loss: 264.8602
# Epoch 4/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 455s 8s/step - accuracy: 0.7587 - loss: 0.6287 - val_accuracy: 0.6539 - val_loss: 3.6633
# Epoch 5/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 453s 8s/step - accuracy: 0.8020 - loss: 0.6667 - val_accuracy: 0.5895 - val_loss: 16.3746
# Epoch 6/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 503s 8s/step - accuracy: 0.8261 - loss: 0.4637 - val_accuracy: 0.7237 - val_loss: 1.7823
# Epoch 7/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 460s 8s/step - accuracy: 0.8433 - loss: 0.6874 - val_accuracy: 0.8039 - val_loss: 1.4629
# Epoch 8/10
# ...

# %% [markdown]
# ### Metricas

# %%
accuracy,precision,recall,f1, auc = Metricas(model_cnn8,X_test,y_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step
# Accuracy: 0.83
# Precision: 0.86
# Recall: 0.83
# F1-Score: 0.83
# AUC: 0.95
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.78      0.87       259
#     Immature       0.87      0.75      0.81       198
#       Mature       0.71      0.95      0.81       257
#
#     accuracy                           0.83       714
#    macro avg       0.86      0.83      0.83       714
# weighted avg       0.86      0.83      0.83       714

# %% [markdown]
# #### Guardar Metricas

# %%
Listas(accuracy,precision,recall,f1, auc,"CNN",8)

# %% [markdown]
# ### Grafica

# %%
Grafica(history_model_cnn8)
